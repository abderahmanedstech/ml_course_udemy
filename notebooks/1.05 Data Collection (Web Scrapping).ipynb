# %% [markdown]
# # Books to Scrape - Scraping Using BeautifulSoup: Basic Version (V1)
#
# ---

# %% [markdown]
# ## Import Library

# %% [markdown]
# ## Step-by-step scraping (before building functions)
# In this section we scrape **one page** first, step by step, then we generalize to multiple pages.
#
# Target website (safe for practice): https://books.toscrape.com/

# %% [markdown]
# ---

# %% [markdown]
# ## Function for Scrapping

# %% [markdown]
# ### Scrapping Function

# %% [markdown]
# ### Function to Scrape Multiple Pages

# %% [markdown]
# ### Function to Save Data to CSV

# %% [markdown]
# ---

# %% [markdown]
# ## Using Function

# %% [markdown]
# ### Using Scrapping Function

# %% [markdown]
# ### Show data on Notebook
